# %% [markdown]
# <a href="https://colab.research.google.com/github/obarnstedt/CEBRA-demos/blob/colab/Demo_hippocampus_multisession.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Technical: Training models across animals

# %% [markdown]
# * This notebook will demo how to use a multisession CEBRA implementation.
# * We will compare embeddings obtained on 4 rat datasets when trained on four single-session models vs. one multisession model.
# * We will use CEBRA-Behavior (``conditional='time_delta'``) for both single and multi session implementation.
# * Each individual single session output embedding is aligned to the first session.
#
#
# **How multi-session training works:**
#
# * For flexibility, it is implemented so that it does not fit one model for all sessions. Consequently, it is possible to use sessions that do not have the same number of data features (e.g., not the same number of neurons from one session to the other). The number of samples can also vary (true for single session too).
# * It fits one model per session but the pos/neg sampling is performed across all sessions, making the models invariant to the labels across all sessions.
#
#
# **When to use multi-session training:**
#
# Check out the following list to verify if our multisession implementation is the right tool for your needs.
#
# * I have multiple sessions or animals that I want to consider as a *pseudo-subject* and use them jointly for training CEBRA.
# * That is the case because of limited access to simultaneously recorded neurons or looking for animal-invariant features in the neural data.
# * I want to get more consistent embeddings from one session or animal to the other.
# * I want to be able to use CEBRA for a new session that is fully *unseen* during training (e.g., could be useful for a brain machine interface applications).
# * **WARNING:** I am not interested in the influence of individual variations of the label features from one session/animal to the other on the resulting embedding. I do not need those session or animal specific information.

# %% [markdown]
# **Install note**
#
# Be sure you have cebra, and the demo dependencies, installed to use this notebook:

# %%
# !pip install 'cebra[datasets,demos]'
# Out:
# Collecting cebra[datasets,demos]
#   Downloading cebra-0.2.0-py2.py3-none-any.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.3/171.3 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from cebra[datasets,demos]) (1.3.2)
# Collecting literate-dataclasses (from cebra[datasets,demos])
#   Downloading literate_dataclasses-0.0.6-py3-none-any.whl (5.0 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from cebra[datasets,demos]) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from cebra[datasets,demos]) (1.11.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from cebra[datasets,demos]) (2.0.1+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from cebra[datasets,demos]) (4.66.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from cebra[datasets,demos]) (3.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from cebra[datasets,demos]) (2.31.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from cebra[datasets,demos]) (3.9.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from cebra[datasets,demos]) (1.5.3)
# Collecting hdf5storage (from cebra[datasets,demos])
#   Downloading hdf5storage-0.1.19-py2.py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (from cebra[datasets,demos]) (3.1.2)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from cebra[datasets,demos]) (5.5.6)
# Collecting jupyter (from cebra[datasets,demos])
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from cebra[datasets,demos]) (6.5.4)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from cebra[datasets,demos]) (0.12.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from h5py->cebra[datasets,demos]) (1.23.5)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipykernel->cebra[datasets,demos]) (0.2.0)
# Requirement already satisfied: ipython>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->cebra[datasets,demos]) (7.34.0)
# Requirement already satisfied: traitlets>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->cebra[datasets,demos]) (5.7.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel->cebra[datasets,demos]) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel->cebra[datasets,demos]) (6.3.2)
# Requirement already satisfied: notebook in /usr/local/lib/python3.10/dist-packages (from jupyter->cebra[datasets,demos]) (6.5.5)
# Collecting qtconsole (from jupyter->cebra[datasets,demos])
#   Downloading qtconsole-5.4.4-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.10/dist-packages (from jupyter->cebra[datasets,demos]) (6.1.0)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from jupyter->cebra[datasets,demos]) (7.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cebra[datasets,demos]) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cebra[datasets,demos]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cebra[datasets,demos]) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cebra[datasets,demos]) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cebra[datasets,demos]) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cebra[datasets,demos]) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cebra[datasets,demos]) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cebra[datasets,demos]) (2.8.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->cebra[datasets,demos]) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->cebra[datasets,demos]) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->cebra[datasets,demos]) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->cebra[datasets,demos]) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->cebra[datasets,demos]) (0.4)
# Requirement already satisfied: jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->cebra[datasets,demos]) (3.1.2)
# Requirement already satisfied: jupyter-core>=4.7 in /usr/local/lib/python3.10/dist-packages (from nbconvert->cebra[datasets,demos]) (5.3.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->cebra[datasets,demos]) (0.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->cebra[datasets,demos]) (2.1.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->cebra[datasets,demos]) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->cebra[datasets,demos]) (0.8.0)
# Requirement already satisfied: nbformat>=5.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->cebra[datasets,demos]) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->cebra[datasets,demos]) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->cebra[datasets,demos]) (2.16.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->cebra[datasets,demos]) (1.2.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl->cebra[datasets,demos]) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->cebra[datasets,demos]) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->cebra[datasets,demos]) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->cebra[datasets,demos]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->cebra[datasets,demos]) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->cebra[datasets,demos]) (2023.7.22)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->cebra[datasets,demos]) (3.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->cebra[datasets,demos]) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->cebra[datasets,demos]) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->cebra[datasets,demos]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->cebra[datasets,demos]) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->cebra[datasets,demos]) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->cebra[datasets,demos]) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->cebra[datasets,demos]) (16.0.6)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->cebra[datasets,demos]) (67.7.2)
# Collecting jedi>=0.16 (from ipython>=5.0.0->ipykernel->cebra[datasets,demos])
#   Downloading jedi-0.19.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 40.0 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->cebra[datasets,demos]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->cebra[datasets,demos]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->cebra[datasets,demos]) (3.0.39)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->cebra[datasets,demos]) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->cebra[datasets,demos]) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->cebra[datasets,demos]) (4.8.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.7->nbconvert->cebra[datasets,demos]) (3.10.0)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel->cebra[datasets,demos]) (23.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.1->nbconvert->cebra[datasets,demos]) (2.18.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.1->nbconvert->cebra[datasets,demos]) (4.19.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->cebra[datasets,demos]) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->cebra[datasets,demos]) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->cebra[datasets,demos]) (0.5.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->jupyter->cebra[datasets,demos]) (3.6.5)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->jupyter->cebra[datasets,demos]) (3.0.8)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->cebra[datasets,demos]) (23.1.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->cebra[datasets,demos]) (1.5.7)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->cebra[datasets,demos]) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->cebra[datasets,demos]) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->cebra[datasets,demos]) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->cebra[datasets,demos]) (1.0.0)
# Collecting qtpy>=2.4.0 (from qtconsole->jupyter->cebra[datasets,demos])
#   Downloading QtPy-2.4.0-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.4/93.4 kB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->cebra[datasets,demos]) (1.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel->cebra[datasets,demos]) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->cebra[datasets,demos]) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->cebra[datasets,demos]) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->cebra[datasets,demos]) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->cebra[datasets,demos]) (0.10.2)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook->jupyter->cebra[datasets,demos]) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook->jupyter->cebra[datasets,demos]) (0.2.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=5.0.0->ipykernel->cebra[datasets,demos]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->cebra[datasets,demos]) (0.2.6)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook->jupyter->cebra[datasets,demos]) (21.2.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->cebra[datasets,demos]) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->cebra[datasets,demos]) (1.6.2)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->cebra[datasets,demos]) (1.15.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->cebra[datasets,demos]) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->cebra[datasets,demos]) (1.1.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->cebra[datasets,demos]) (2.21)
# Installing collected packages: qtpy, literate-dataclasses, jedi, hdf5storage, qtconsole, jupyter, cebra
# Successfully installed cebra-0.2.0 hdf5storage-0.1.19 jedi-0.19.0 jupyter-1.0.0 literate-dataclasses-0.0.6 qtconsole-5.4.4 qtpy-2.4.0

# %%
import sys
import os

import cebra.data
import cebra.datasets
import cebra.integrations
from cebra import CEBRA
import pickle

import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# check if notebook run in Colab:
try:
  import google.colab
  IN_COLAB = True
  # %matplotlib inline
except:
  IN_COLAB = False
  # %matplotlib notebook
# Out:
# /usr/local/lib/python3.10/dist-packages/cebra/datasets/monkey_reaching.py:35: UserWarning: Could not import the nlb_tools package required for data loading of cebra.datasets.monkey_reaching. Dataset will not be available. If required, you can install the dataset by running pip install git+https://github.com/neurallatents/nlb_tools.
#   warnings.warn(

# %% [markdown]
# ## Load the data

# %% [markdown]
# - The data will be automatically downloaded into a `/data` folder.

# %%
if IN_COLAB and not os.path.exists('/content/data/rat_hippocampus'):
    import locale
    locale.getpreferredencoding = lambda: "UTF-8"  # to prevent locale errors
    #for google colab only, run this cell to download and extract data:
    # !wget --content-disposition https://figshare.com/ndownloader/files/36869049?private_link=60adb075234c2cc51fa3
    # !mkdir data
    # !tar -xvf "/content/data.tgz" -C "/content/data"

hippocampus_a = cebra.datasets.init('rat-hippocampus-single-achilles')
hippocampus_b = cebra.datasets.init('rat-hippocampus-single-buddy')
hippocampus_c = cebra.datasets.init('rat-hippocampus-single-cicero')
hippocampus_g = cebra.datasets.init('rat-hippocampus-single-gatsby')
# Out:
# --2023-09-16 13:01:35--  https://figshare.com/ndownloader/files/36869049?private_link=60adb075234c2cc51fa3
# Resolving figshare.com (figshare.com)... 52.19.197.201, 176.34.206.43, 2a05:d018:1f4:d003:ca7c:7587:e6e5:533c, ...
# Connecting to figshare.com (figshare.com)|52.19.197.201|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/36869049/data.tgz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIYCQYOYV5JSSROOA/20230916/eu-west-1/s3/aws4_request&X-Amz-Date=20230916T130136Z&X-Amz-Expires=10&X-Amz-SignedHeaders=host&X-Amz-Signature=7d92d0115c858d41d3933b0ccaecde9c5133299564b38ea61ad673b56a0c22ba [following]
# --2023-09-16 13:01:36--  https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/36869049/data.tgz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIYCQYOYV5JSSROOA/20230916/eu-west-1/s3/aws4_request&X-Amz-Date=20230916T130136Z&X-Amz-Expires=10&X-Amz-SignedHeaders=host&X-Amz-Signature=7d92d0115c858d41d3933b0ccaecde9c5133299564b38ea61ad673b56a0c22ba
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 52.218.44.112, 52.218.88.115, 52.218.20.60, ...
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|52.218.44.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3135829221 (2.9G) [application/x-gtar-compressed]
# Saving to: ‘data.tgz’
#
# data.tgz            100%[===================>]   2.92G  26.9MB/s    in 1m 52s
#
# 2023-09-16 13:03:28 (26.7 MB/s) - ‘data.tgz’ saved [3135829221/3135829221]
#
# ./
# ./rat_hippocampus/
# ./rat_hippocampus/cicero.jl
# ./rat_hippocampus/buddy.jl
# ./rat_hippocampus/gatsby.jl
# ./rat_hippocampus/achilles.jl
# ./monkey_reaching_preload_smth_40/
# ./monkey_reaching_preload_smth_40/passive_all.jl
# ./monkey_reaching_preload_smth_40/active_train.jl
# ./monkey_reaching_preload_smth_40/active_valid.jl
# ./monkey_reaching_preload_smth_40/active_all.jl
# ./monkey_reaching_preload_smth_40/passive_valid.jl
# ./monkey_reaching_preload_smth_40/all_test.jl
# ./monkey_reaching_preload_smth_40/passive_test.jl
# ./monkey_reaching_preload_smth_40/all_valid.jl
# ./monkey_reaching_preload_smth_40/active_test.jl
# ./monkey_reaching_preload_smth_40/all_train.jl
# ./monkey_reaching_preload_smth_40/passive_train.jl
# ./monkey_reaching_preload_smth_40/all_all.jl
# ./allen/
# ./allen/allen_movie1_neuropixel/
# ./allen/allen_movie1_neuropixel/VISp/
# ./allen/allen_movie1_neuropixel/VISp/neuropixel_pseudomouse_120_filtered.jl
# ./allen/allen_movie1_neuropixel/VISp/neuropixel_pseudomouse_120.jl
# ./allen/allen_movie1_neuropixel/VISp/neuropixel_sessions_0.01.jl
# ./allen/allen_movie1_neuropixel/VISp/neuropixel_pseudomouse_0.01.jl
# ./allen/allen_movie1_neuropixel/VISal/
# ./allen/allen_movie1_neuropixel/VISal/neuropixel_pseudomouse_120_filtered.jl
# ./allen/allen_movie1_neuropixel/VISal/neuropixel_sessions_120_filtered.jl
# ./allen/allen_movie1_neuropixel/VISpm/
# ./allen/allen_movie1_neuropixel/VISpm/neuropixel_pseudomouse_120_filtered.jl
# ./allen/allen_movie1_neuropixel/VISpm/neuropixel_sessions_120_filtered.jl
# ./allen/allen_movie1_neuropixel/VISl/
# ./allen/allen_movie1_neuropixel/VISl/neuropixel_pseudomouse_120_filtered.jl
# ./allen/allen_movie1_neuropixel/VISl/neuropixel_sessions_120_filtered.jl
# ./allen/allen_movie1_neuropixel/VISrl/
# ./allen/allen_movie1_neuropixel/VISrl/neuropixel_pseudomouse_120_filtered.jl
# ./allen/allen_movie1_neuropixel/VISrl/neuropixel_sessions_120.0_filtered.jl
# ./allen/allen_movie1_neuropixel/VISam/
# ./allen/allen_movie1_neuropixel/VISam/neuropixel_pseudomouse_120_filtered.jl
# ./allen/allen_movie1_neuropixel/VISam/neuropixel_sessions_120_filtered.jl
# ./allen/features/
# ./allen/features/allen_manual_annotation.csv
# ./allen/features/allen_movies/
# ./allen/features/allen_movies/vit_small/
# ./allen/features/allen_movies/vit_small/16/
# ./allen/features/allen_movies/vit_small/16/movie_two_image_stack.npz/
# ./allen/features/allen_movies/vit_small/16/movie_two_image_stack.npz/210902-035956-767677376_knn.log.done
# ./allen/features/allen_movies/vit_small/16/movie_two_image_stack.npz/210902-035956-767677376_knn.log
# ./allen/features/allen_movies/vit_small/16/movie_two_image_stack.npz/testfeat.pth
# ./allen/features/allen_movies/vit_small/16/movie_one_image_stack.npz/
# ./allen/features/allen_movies/vit_small/16/movie_one_image_stack.npz/210902-035956-027351662_knn.log.done
# ./allen/features/allen_movies/vit_small/16/movie_one_image_stack.npz/210902-035956-027351662_knn.log
# ./allen/features/allen_movies/vit_small/16/movie_one_image_stack.npz/testfeat.pth
# ./allen/features/allen_movies/vit_small/16/movie_three_image_stack.npz/
# ./allen/features/allen_movies/vit_small/16/movie_three_image_stack.npz/210902-035955-993569469_knn.log.done
# ./allen/features/allen_movies/vit_small/16/movie_three_image_stack.npz/testfeat.pth
# ./allen/features/allen_movies/vit_small/16/movie_three_image_stack.npz/210902-035955-993569469_knn.log
# ./allen/features/allen_movies/vit_small/8/
# ./allen/features/allen_movies/vit_small/8/movie_two_image_stack.npz/
# ./allen/features/allen_movies/vit_small/8/movie_two_image_stack.npz/testfeat.pth
# ./allen/features/allen_movies/vit_small/8/movie_two_image_stack.npz/210902-035956-078206348_knn.log
# ./allen/features/allen_movies/vit_small/8/movie_two_image_stack.npz/210902-035956-078206348_knn.log.done
# ./allen/features/allen_movies/vit_small/8/movie_one_image_stack.npz/
# ./allen/features/allen_movies/vit_small/8/movie_one_image_stack.npz/testfeat.pth
# ./allen/features/allen_movies/vit_small/8/movie_one_image_stack.npz/210902-035956-022653585_knn.log
# ./allen/features/allen_movies/vit_small/8/movie_one_image_stack.npz/210902-035956-022653585_knn.log.done
# ./allen/features/allen_movies/vit_small/8/movie_three_image_stack.npz/
# ./allen/features/allen_movies/vit_small/8/movie_three_image_stack.npz/testfeat.pth
# ./allen/features/allen_movies/vit_small/8/movie_three_image_stack.npz/210902-035956-529188565_knn.log
# ./allen/features/allen_movies/vit_small/8/movie_three_image_stack.npz/210902-035956-529188565_knn.log.done
# ./allen/features/allen_movies/vit_base/
# ./allen/features/allen_movies/vit_base/16/
# ./allen/features/allen_movies/vit_base/16/movie_two_image_stack.npz/
# ./allen/features/allen_movies/vit_base/16/movie_two_image_stack.npz/210902-035957-052096187_knn.log.done
# ./allen/features/allen_movies/vit_base/16/movie_two_image_stack.npz/testfeat.pth
# ./allen/features/allen_movies/vit_base/16/movie_two_image_stack.npz/210902-035957-052096187_knn.log
# ./allen/features/allen_movies/vit_base/16/movie_one_image_stack.npz/
# ./allen/features/allen_movies/vit_base/16/movie_one_image_stack.npz/testfeat.pth
# ./allen/features/allen_movies/vit_base/16/movie_one_image_stack.npz/210902-035954-767565646_knn.log.done
# ./allen/features/allen_movies/vit_base/16/movie_one_image_stack.npz/210902-035954-767565646_knn.log
# ./allen/features/allen_movies/vit_base/16/movie_three_image_stack.npz/
# ./allen/features/allen_movies/vit_base/16/movie_three_image_stack.npz/210902-035955-996459874_knn.log
# ./allen/features/allen_movies/vit_base/16/movie_three_image_stack.npz/testfeat.pth
# ./allen/features/allen_movies/vit_base/16/movie_three_image_stack.npz/210902-035955-996459874_knn.log.done
# ./allen/features/allen_movies/vit_base/8/
# ./allen/features/allen_movies/vit_base/8/movie_two_image_stack.npz/
# ./allen/features/allen_movies/vit_base/8/movie_two_image_stack.npz/210902-035956-602389316_knn.log.done
# ./allen/features/allen_movies/vit_base/8/movie_two_image_stack.npz/testfeat.pth
# ./allen/features/allen_movies/vit_base/8/movie_two_image_stack.npz/210902-035956-602389316_knn.log
# ./allen/features/allen_movies/vit_base/8/movie_one_image_stack.npz/
# ./allen/features/allen_movies/vit_base/8/movie_one_image_stack.npz/210902-035955-367773914_knn.log.done
# ./allen/features/allen_movies/vit_base/8/movie_one_image_stack.npz/210902-035955-367773914_knn.log
# ./allen/features/allen_movies/vit_base/8/movie_one_image_stack.npz/testfeat.pth
# ./allen/features/allen_movies/vit_base/8/movie_three_image_stack.npz/
# ./allen/features/allen_movies/vit_base/8/movie_three_image_stack.npz/testfeat.pth
# ./allen/features/allen_movies/vit_base/8/movie_three_image_stack.npz/210902-035956-650529316_knn.log
# ./allen/features/allen_movies/vit_base/8/movie_three_image_stack.npz/210902-035956-650529316_knn.log.done
# ./allen/data_summary.csv
# ./allen/visual_drift/
# ./allen/visual_drift/data/
# ./allen/visual_drift/data/neuropixels/
# ./allen/visual_drift/data/neuropixels/session_793224716.mat
# ./allen/visual_drift/data/neuropixels/session_742951821.mat
# ./allen/visual_drift/data/neuropixels/session_746083955.mat
# ./allen/visual_drift/data/neuropixels/session_787025148.mat
# ./allen/visual_drift/data/neuropixels/session_781842082.mat
# ./allen/visual_drift/data/neuropixels/session_750332458.mat
# ./allen/visual_drift/data/neuropixels/session_794812542.mat
# ./allen/visual_drift/data/neuropixels/session_739448407.mat
# ./allen/visual_drift/data/neuropixels/session_786091066.mat
# ./allen/visual_drift/data/neuropixels/session_847657808.mat
# ./allen/visual_drift/data/neuropixels/session_743475441.mat
# ./allen/visual_drift/data/neuropixels/session_768515987.mat
# ./allen/visual_drift/data/neuropixels/session_766640955.mat
# ./allen/visual_drift/data/neuropixels/session_819701982.mat
# ./allen/visual_drift/data/neuropixels/session_759883607.mat
# ./allen/visual_drift/data/neuropixels/session_835479236.mat
# ./allen/visual_drift/data/neuropixels/session_763673393.mat
# ./allen/visual_drift/data/neuropixels/session_798911424.mat
# ./allen/visual_drift/data/neuropixels/session_839557629.mat
# ./allen/visual_drift/data/neuropixels/session_839068429.mat
# ./allen/visual_drift/data/neuropixels/session_778240327.mat
# ./allen/visual_drift/data/neuropixels/session_737581020.mat
# ./allen/visual_drift/data/neuropixels/session_757216464.mat
# ./allen/visual_drift/data/neuropixels/session_750749662.mat
# ./allen/visual_drift/data/neuropixels/session_779839471.mat
# ./allen/visual_drift/data/neuropixels/session_799864342.mat
# ./allen/visual_drift/data/neuropixels/session_751348571.mat
# ./allen/visual_drift/data/neuropixels/session_721123822.mat
# ./allen/visual_drift/data/neuropixels/session_744228101.mat
# ./allen/visual_drift/data/neuropixels/session_762602078.mat
# ./allen/visual_drift/data/neuropixels/session_778998620.mat
# ./allen/visual_drift/data/neuropixels/session_767871931.mat
# ./allen/visual_drift/data/neuropixels/session_821695405.mat
# ./allen/visual_drift/data/neuropixels/session_831882777.mat
# ./allen/visual_drift/data/neuropixels/session_771160300.mat
# ./allen/visual_drift/data/neuropixels/session_715093703.mat
# ./allen/visual_drift/data/neuropixels/session_758798717.mat
# ./allen/visual_drift/data/neuropixels/session_754312389.mat
# ./allen/visual_drift/data/neuropixels/session_760345702.mat
# ./allen/visual_drift/data/neuropixels/session_754829445.mat
# ./allen/visual_drift/data/neuropixels/session_760693773.mat
# ./allen/visual_drift/data/neuropixels/session_774875821.mat
# ./allen/visual_drift/data/neuropixels/session_761418226.mat
# ./allen/visual_drift/data/neuropixels/session_755434585.mat
# ./allen/visual_drift/data/neuropixels/session_719161530.mat
# ./allen/visual_drift/data/neuropixels/session_829720705.mat
# ./allen/visual_drift/data/neuropixels/session_756029989.mat
# ./allen/visual_drift/data/neuropixels/session_840012044.mat
# ./allen/visual_drift/data/neuropixels/session_757970808.mat
# ./allen/visual_drift/data/neuropixels/session_762120172.mat
# ./allen/visual_drift/data/neuropixels/session_819186360.mat
# ./allen/visual_drift/data/neuropixels/session_816200189.mat
# ./allen/visual_drift/data/neuropixels/session_789848216.mat
# ./allen/visual_drift/data/neuropixels/session_732592105.mat
# ./allen/visual_drift/data/neuropixels/session_771990200.mat
# ./allen/visual_drift/data/neuropixels/session_773418906.mat
# ./allen/visual_drift/data/neuropixels/session_791319847.mat
# ./allen/visual_drift/data/neuropixels/session_797828357.mat
# ./allen/visual_drift/data/calcium_inhibitory/
# ./allen/visual_drift/data/calcium_inhibitory/VISp/
# ./allen/visual_drift/data/calcium_inhibitory/VISp/672223113.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/657390169.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/657078117.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/617395453.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/659491615.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/614418789.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/671618885.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/670721865.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/583279801.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/676503586.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/657775945.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/579992884.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/604866830.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/582621871.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/658518484.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/573720506.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/657389970.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/670396939.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/667772494.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/582804903.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/680150731.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/652842493.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/606130900.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/612543997.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/658536326.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/582925971.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/580043437.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/686449283.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/575940387.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/598635819.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/662361094.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/575827179.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/595620996.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/580163815.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/612044633.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/669859917.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/712178481.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/673914979.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/577379200.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/581026086.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/710504561.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/710327593.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/657650108.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/584829664.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/669876048.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/601259497.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/667692761.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/674679297.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/650079242.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISp/652091262.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/603763385.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/649324896.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/607426688.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/685063218.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/602397921.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/596557967.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/658020689.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/603425657.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/650389905.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/617388115.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/601374504.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/657776354.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/652092000.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/685816034.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/603452149.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/589253442.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/599920955.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/601273919.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/696156781.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/647598517.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/646959440.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/626027942.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/689402243.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/598584901.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/689385402.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/640210564.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/639117194.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/639251930.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/638870774.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISpm/627823202.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/
# ./allen/visual_drift/data/calcium_inhibitory/VISl/686031104.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/652092674.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/657009579.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/602589529.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/601805377.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/601871316.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/617047314.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/686449090.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/603452289.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/612549083.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/580095653.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/606960910.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/686442554.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/671164925.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/673475018.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/673477065.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/614556104.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/714778444.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/627823633.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/657472844.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/659752540.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/583787531.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/601841435.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/584778281.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/650390040.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/597028936.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/593337825.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/582867145.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/657224239.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/575772104.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/676024664.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/614571624.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/601547953.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/603316204.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/581676514.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/606802465.mat
# ./allen/visual_drift/data/calcium_inhibitory/VISl/601812178.mat
# ./allen/visual_drift/data/calcium_excitatory/
# ./allen/visual_drift/data/calcium_excitatory/VISp/
# ./allen/visual_drift/data/calcium_excitatory/VISp/617381603.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/512124562.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/679702882.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/656939125.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/658536109.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/653932503.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/543677425.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/598564171.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/602616431.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/511510955.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/649401934.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/526481129.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/659746623.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/637671552.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/666589599.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/616886391.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/650389885.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/686912320.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/637115672.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/637669268.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/661732156.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/511510675.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/528889127.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/682734790.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/647155120.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/511509529.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/561312433.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/662974313.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/511510650.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/586351979.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/660065749.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/590168381.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/545578995.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/595906107.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/511510989.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/529763300.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/642651896.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/511510718.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/712178509.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/555040113.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/592655325.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/661437138.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/648377366.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/511498742.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/546724786.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/680156909.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/674802081.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/535575493.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/702934962.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/517328083.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/701412138.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/595263152.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/653125128.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/603425700.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/540993888.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/571137444.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/527676429.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/688678764.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/539291370.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/570278595.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/511510896.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/511510779.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/637998953.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/536323956.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/511510855.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/657082052.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/627823571.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/603576130.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/530739574.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/540168835.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/511510736.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/653122665.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/645413757.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/661744802.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/524691282.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/538803515.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/511507650.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/659767480.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/643592301.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/588503721.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/511510667.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/665722299.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/511510670.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/511510911.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/644909309.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/658816711.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/511510699.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/627823692.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/652842570.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/528792730.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/595806298.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/531134088.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/657016265.mat
# ./allen/visual_drift/data/calcium_excitatory/VISp/511507811.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/
# ./allen/visual_drift/data/calcium_excitatory/VISal/698102441.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/556936291.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/511510723.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/572376866.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/511510794.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/555700037.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/555042465.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/560753319.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/591460068.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/511856567.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/638056632.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/511499656.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/511510695.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/572607996.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/685816004.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/560876149.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/511510715.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/564791547.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/584944063.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/569396922.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/584475415.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/511500480.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/562536151.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/593506466.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/511854338.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/511510867.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/511510664.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/511511052.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/511510797.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/511510998.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/511510860.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/637113170.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/556639822.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/564791561.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/511510710.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/604576635.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/639253041.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/561472631.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/563364151.mat
# ./allen/visual_drift/data/calcium_excitatory/VISal/546328009.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/
# ./allen/visual_drift/data/calcium_excitatory/VISpm/511510940.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/665413463.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/551888517.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/669239850.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/549855418.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/653126875.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/657785848.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/511510893.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/575766605.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/586452279.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/511511015.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/511510658.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/557986062.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/701046698.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/555749366.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/569611977.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/652096181.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/554014018.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/561463418.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/644947714.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/511976252.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/599112785.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/574529963.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/511510817.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/658854535.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/703308069.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/657470854.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/637126539.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/658534530.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/560809200.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/638753614.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/511511006.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/716655272.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/511510836.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/657391035.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/565039910.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/554037268.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/511510748.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/670721587.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/604529228.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/657014785.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/650389951.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/511510645.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/679700455.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/560821491.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/662172425.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/571684731.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/511510753.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/511511001.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/673144414.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/511511083.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/511510822.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/603519606.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/556936862.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/686441797.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/645690244.mat
# ./allen/visual_drift/data/calcium_excitatory/VISpm/669859473.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/
# ./allen/visual_drift/data/calcium_excitatory/VISl/665726616.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/653551963.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/609198028.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/575771818.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/650510286.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/643590699.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/647595663.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/639929073.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/529487170.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/651773425.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/651366508.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/554219902.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/584155531.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/559792042.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/558476280.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/511510917.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/557520762.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/623587004.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/644061873.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/672207945.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/610222464.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/650885966.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/696503438.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/644013840.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/606872639.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/663488406.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/511511029.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/511510763.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/511510627.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/646686776.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/511511011.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/662219850.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/702956471.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/573261513.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/551657958.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/658854759.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/511510848.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/566480479.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/653123584.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/601790879.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/670395723.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/511510870.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/573378109.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/547561986.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/564425775.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/682049097.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/699155263.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/572606380.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/511510994.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/558471484.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/511510945.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/669237513.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/707923643.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/662358769.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/676503916.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/511510688.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/605883131.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/546085409.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/511511089.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/511510640.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/657391623.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/643667453.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/595337948.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/652736297.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/560578597.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/547315012.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/646016202.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/666271537.mat
# ./allen/visual_drift/data/calcium_excitatory/VISl/583136565.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/
# ./allen/visual_drift/data/calcium_excitatory/VISrl/702208910.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/570008442.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/603502696.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/574034739.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/593270600.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/570428250.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/595718340.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/657804822.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/569981238.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/614561352.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/710502979.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/588196040.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/593438035.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/573864648.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/643061996.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/569645688.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/575710989.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/662351162.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/612536909.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/571541563.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/698260530.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/588191924.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/576208803.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/576714442.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/604328040.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/640198007.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/593508592.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/591548031.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/553568029.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/591430488.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/571039045.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/660064794.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/592349242.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/575892535.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/580051757.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/591392164.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/660510591.mat
# ./allen/visual_drift/data/calcium_excitatory/VISrl/560782654.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/
# ./allen/visual_drift/data/calcium_excitatory/VISam/593902385.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/652094915.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/559645337.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/701048110.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/550127305.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/569287964.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/616779891.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/555327033.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/560821337.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/569792815.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/552760668.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/556665479.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/601498409.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/556899621.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/595273801.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/570994450.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/577720109.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/604889966.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/638262555.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/566307034.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/708949511.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/569251675.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/609479771.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/627823721.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/642278280.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/569718095.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/576411244.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/575302106.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/560722730.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/566458503.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/566759225.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/551412603.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/568461662.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/612555401.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/564791582.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/565216521.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/646959386.mat
# ./allen/visual_drift/data/calcium_excitatory/VISam/710469197.mat
# ./allen/visual_drift/data/colormaps/
# ./allen/visual_drift/data/colormaps/new_jet_colormap.mat
# ./allen/visual_drift/data/colormaps/magma_colormap.mat
# ./allen/visual_drift/data/colormaps/newmap3.mat
# ./allen/visual_drift/data/colormaps/sig_colormap.mat
# ./allen/visual_drift/data/seeds/
# ./allen/visual_drift/data/seeds/FigureS7E.mat
# ./allen/visual_drift/data/seeds/FigureS7A_calcium.mat
# ./allen/visual_drift/data/seeds/Figure6A.mat
# ./allen/visual_drift/data/seeds/neuropixels_structure_STATE1.mat
# ./allen/visual_drift/data/seeds/neuropixels_structure_STATE6.mat
# ./allen/visual_drift/data/seeds/neuropixels_structure_STATE4.mat
# ./allen/visual_drift/data/seeds/neuropixels_structure_STATE5.mat
# ./allen/visual_drift/data/seeds/Figure6D.mat
# ./allen/visual_drift/data/seeds/neuropixels_structure_STATE3.mat
# ./allen/visual_drift/data/seeds/Figure6C.mat
# ./allen/visual_drift/data/seeds/FigureS7A_neuropixels.mat
# ./allen/visual_drift/data/seeds/neuropixels_structure_STATE2.mat
# ./allen/visual_drift/data/seeds/neuropixels_structure_ind.mat
# ./allen/visual_drift/data/seeds/Figure7A.mat
# ./allen/visual_drift/data/seeds/Figure6E.mat
# ./allen/visual_drift/LICENSE
# ./allen/visual_drift/README.md
# ./allen/visual_drift/.git/
# ./allen/visual_drift/.git/description
# ./allen/visual_drift/.git/logs/
# ./allen/visual_drift/.git/logs/refs/
# ./allen/visual_drift/.git/logs/refs/remotes/
# ./allen/visual_drift/.git/logs/refs/remotes/origin/
# ./allen/visual_drift/.git/logs/refs/remotes/origin/HEAD
# ./allen/visual_drift/.git/logs/refs/heads/
# ./allen/visual_drift/.git/logs/refs/heads/main
# ./allen/visual_drift/.git/logs/HEAD
# ./allen/visual_drift/.git/refs/
# ./allen/visual_drift/.git/refs/remotes/
# ./allen/visual_drift/.git/refs/remotes/origin/
# ./allen/visual_drift/.git/refs/remotes/origin/HEAD
# ./allen/visual_drift/.git/refs/heads/
# ./allen/visual_drift/.git/refs/heads/main
# ./allen/visual_drift/.git/refs/tags/
# ./allen/visual_drift/.git/objects/
# ./allen/visual_drift/.git/objects/info/
# ./allen/visual_drift/.git/objects/pack/
# ./allen/visual_drift/.git/objects/pack/pack-e153fe32765c6e4beeee7cb1e4b9a8ff8bbca115.pack
# ./allen/visual_drift/.git/objects/pack/pack-e153fe32765c6e4beeee7cb1e4b9a8ff8bbca115.idx
# ./allen/visual_drift/.git/packed-refs
# ./allen/visual_drift/.git/config
# ./allen/visual_drift/.git/branches/
# ./allen/visual_drift/.git/hooks/
# ./allen/visual_drift/.git/hooks/post-update.sample
# ./allen/visual_drift/.git/hooks/commit-msg.sample
# ./allen/visual_drift/.git/hooks/prepare-commit-msg.sample
# ./allen/visual_drift/.git/hooks/update.sample
# ./allen/visual_drift/.git/hooks/pre-receive.sample
# ./allen/visual_drift/.git/hooks/pre-push.sample
# ./allen/visual_drift/.git/hooks/pre-merge-commit.sample
# ./allen/visual_drift/.git/hooks/pre-commit.sample
# ./allen/visual_drift/.git/hooks/applypatch-msg.sample
# ./allen/visual_drift/.git/hooks/pre-applypatch.sample
# ./allen/visual_drift/.git/hooks/pre-rebase.sample
# ./allen/visual_drift/.git/hooks/fsmonitor-watchman.sample
# ./allen/visual_drift/.git/info/
# ./allen/visual_drift/.git/info/exclude
# ./allen/visual_drift/.git/HEAD
# ./allen/visual_drift/.git/index
# ./allen/visual_drift/scripts/
# ./allen/visual_drift/scripts/visual_drift_analysis.m
# ./allen/visual_drift/scripts/violin.m
# ./allen/visual_drift/scripts/bonf_holm.m
# ./allen/visual_drift/scripts/figure_boxplot.m
# ./allen/visual_drift/scripts/dscatter.m
# ./synthetic/
# ./synthetic/continuous_label_uniform.jl
# ./synthetic/continuous_label_gaussian.jl
# ./synthetic/continuous_label_laplace.jl
# ./synthetic/continuous_label_t.jl
# ./synthetic/sim_100d_poisson_cont_label.npz
# ./synthetic/continuous_label_refractory_poisson.jl
# ./synthetic/continuous_poisson_gaussian_noise.jl
# ./synthetic/continuous_label_poisson.jl

# %%
names = ["achilles", "buddy", "cicero", "gatsby"]
datas = [hippocampus_a.neural.numpy(), hippocampus_b.neural.numpy(), hippocampus_c.neural.numpy(), hippocampus_g.neural.numpy()]
labels = [hippocampus_a.continuous_index.numpy(), hippocampus_b.continuous_index.numpy(), hippocampus_c.continuous_index.numpy(), hippocampus_g.continuous_index.numpy()]

# %% [markdown]
# ## Single-session training
#
# Create and fit one single session model per dataset

# %%
max_iterations = 15000 # by default, 5000 iterations

# %%
embeddings = dict()

# Single session training
for name, X, y in zip(names, datas, labels):
    # Fit one CEBRA model per session (i.e., per rat)
    print(f"Fitting CEBRA for {name}")
    cebra_model = CEBRA(model_architecture='offset10-model',
                        batch_size=512,
                        learning_rate=3e-4,
                        temperature=1,
                        output_dimension=3,
                        max_iterations=max_iterations,
                        distance='cosine',
                        conditional='time_delta',
                        device='cuda_if_available',
                        verbose=True,
                        time_offsets=10)

    cebra_model.fit(X, y)
    embeddings[name] = cebra_model.transform(X)


# Align the single session embeddings to the first rat
alignment = cebra.data.helper.OrthogonalProcrustesAlignment()
first_rat = list(embeddings.keys())[0]

for j, rat_name in enumerate(list(embeddings.keys())[1:]):
    embeddings[f"{rat_name}"] = alignment.fit_transform(
        embeddings[first_rat], embeddings[rat_name], labels[0], labels[j+1])


# Save embeddings in current folder
with open('embeddings.pkl', 'wb') as f:
    pickle.dump(embeddings, f)
# Out:
# Fitting CEBRA for achilles
# pos:  0.1626 neg:  5.4230 total:  5.5856 temperature:  1.0000:   5%|▍         | 746/15000 [02:26<42:35,  5.58it/s]

# %% [markdown]
# ## Multisession training
#
# Create and fit one multi-session model on all datasets

# %%
multi_embeddings = dict()

# Multisession training
multi_cebra_model = CEBRA(model_architecture='offset10-model',
                    batch_size=512,
                    learning_rate=3e-4,
                    temperature=1,
                    output_dimension=3,
                    max_iterations=max_iterations,
                    distance='cosine',
                    conditional='time_delta',
                    device='cuda_if_available',
                    verbose=True,
                    time_offsets=10)

# Provide a list of data, i.e. datas = [data_a, data_b, ...]
multi_cebra_model.fit(datas, labels)

# Transform each session with the right model, by providing the corresponding session ID
for i, (name, X) in enumerate(zip(names, datas)):
    multi_embeddings[name] = multi_cebra_model.transform(X, session_id=i)

# Save embeddings in current folder
with open('multi_embeddings.pkl', 'wb') as f:
    pickle.dump(multi_embeddings, f)

# %% [markdown]
# ## Compare embeddings
#
# Also see [Extended Data Figure 7](https://cebra.ai/docs/cebra-figures/figures/ExtendedDataFigure7.html) of Schneider, Lee, Mathis.

# %%
with open('embeddings.pkl', 'rb') as f:
    embeddings = pickle.load(f)
with open('multi_embeddings.pkl', 'rb') as f:
    multi_embeddings = pickle.load(f)

# %%
def plot_hippocampus(ax, embedding, label, gray = False, idx_order = (0,1,2)):
    r_ind = label[:,1] == 1
    l_ind = label[:,2] == 1

    if not gray:
        r_cmap = 'cool'
        l_cmap = 'viridis'
        r_c = label[r_ind, 0]
        l_c = label[l_ind, 0]
    else:
        r_cmap = None
        l_cmap = None
        r_c = 'gray'
        l_c = 'gray'

    idx1, idx2, idx3 = idx_order
    r=ax.scatter(embedding [r_ind,idx1],
               embedding [r_ind,idx2],
               embedding [r_ind,idx3],
               c=r_c,
               cmap=r_cmap, s=0.05, alpha=0.75)
    l=ax.scatter(embedding [l_ind,idx1],
               embedding [l_ind,idx2],
               embedding [l_ind,idx3],
               c=l_c,
               cmap=l_cmap, s=0.05, alpha=0.75)

    ax.grid(False)
    ax.xaxis.pane.fill = False
    ax.yaxis.pane.fill = False
    ax.zaxis.pane.fill = False
    ax.xaxis.pane.set_edgecolor('w')
    ax.yaxis.pane.set_edgecolor('w')
    ax.zaxis.pane.set_edgecolor('w')

    return ax

def plot_hippocampus_plotly(fig, col, embedding, label, row=0, gray=False, idx_order=(0,1,2)):
    r_ind = label[:,1] == 1
    l_ind = label[:,2] == 1

    if not gray:
        # r_cmap = 'Plotly3'  # 'cool' does not exist in plotly
        r_cmap = ["#00fdff", "#ff40ff"]
        l_cmap = 'viridis'
        r_c = label[r_ind, 0]
        l_c = label[l_ind, 0]
    else:
        r_cmap = None
        l_cmap = None
        r_c = 'gray'
        l_c = 'gray'

    idx1, idx2, idx3 = idx_order

    fig.add_trace(
        go.Scatter3d(
            x=embedding[r_ind, idx1],
            y=embedding[r_ind, idx2],
            z=embedding[r_ind, idx3],
            mode='markers',
            marker=dict(
                size=2,
                opacity=0.6,
                color=r_c,   # set color to an array/list of desired values
                colorscale=r_cmap,   # choose a colorscale
                line=dict(width=0)
            ),
        ), col=col+1, row=row+1)

    fig.add_trace(
        go.Scatter3d(
            x=embedding[l_ind, idx1],
            y=embedding[l_ind, idx2],
            z=embedding[l_ind, idx3],
            mode='markers',
            marker=dict(
                size=2,
                opacity=0.6,
                color=l_c,   # set color to an array/list of desired values
                colorscale=l_cmap,   # choose a colorscale
                line=dict(width=0)
            ),
        ), col=col+1, row=row+1)

    return fig

# %%
plotly = True
if plotly:
    fig = make_subplots(rows=2, cols=4,
                        specs=[[{'is_3d': True}]*4, ],
                        print_grid=False,
                        subplot_titles=([f'Single-{n}' for n in names]+
                                        [f'Multi-{n}' for n in names]),
                        horizontal_spacing = 0.05,
    )
    for i, n in enumerate(names):
        plot_hippocampus_plotly(fig, i, embeddings[n], labels[n])
        plot_hippocampus_plotly(fig, i, embeddings[n], labels[n])
        plot_hippocampus_plotly(fig, i, embeddings[n], labels[n])
        plot_hippocampus_plotly(fig, i, embeddings[n], labels[n])
    for i, n in enumerate(names):
        plot_hippocampus_plotly(fig, i, multi_embeddings[n], labels[n], row=1)
        plot_hippocampus_plotly(fig, i, multi_embeddings[n], labels[n], row=1)
        plot_hippocampus_plotly(fig, i, multi_embeddings[n], labels[n], row=1)
        plot_hippocampus_plotly(fig, i, multi_embeddings[n], labels[n], row=1)
    fig.update_layout(template="plotly_white", showlegend=False, height=400)
    fig.show()

else:
    fig = plt.figure(figsize=(10,6))

    ax1 = plt.subplot(241, projection='3d')
    ax2 = plt.subplot(242, projection='3d')
    ax3 = plt.subplot(243, projection='3d')
    ax4 = plt.subplot(244, projection='3d')
    axs = [ax1, ax2, ax3, ax4]

    ax5 = plt.subplot(245, projection='3d')
    ax6 = plt.subplot(246, projection='3d')
    ax7 = plt.subplot(247, projection='3d')
    ax8 = plt.subplot(248, projection='3d')
    axs_multi = [ax5, ax6, ax7, ax8]

    for name, label, ax, ax_multi in zip(names, labels, axs, axs_multi):
        ax = plot_hippocampus(ax, embeddings[name], label)
        ax.set_title(f'Single-{name}', y=1, pad=-20)
        ax.axis('off')
        ax_multi = plot_hippocampus(ax_multi, multi_embeddings[name], label)
        ax_multi.set_title(f'Multi-{name}', y=1, pad=-20)
        ax_multi.axis('off')


    plt.subplots_adjust(wspace=0,
                        hspace=0)
    plt.show()
